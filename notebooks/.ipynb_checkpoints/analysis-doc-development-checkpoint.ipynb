# %% [markdown]
# ## Develop the analysis-doc git project

# %%
# %matplotlib inline
import os,sys, random, pickle
import numpy as np 
sys.path[0]='C:\\Users\\Toby\\OneDrive\\git\\analysis-doc'
analysis_root = 'C:/Users/Toby/OneDrive/test_plotting/'
os.chdir(analysis_root)
data = np.array([random.gauss(0,1) for n in range(1000)])
pickle.dump(data, open('data.pickle', 'w'))

# %%
from analysis_base import (config, _html, analysis_base)
map(reload, ( config, _html, analysis_base)) 
from example import an_analysis; reload(an_analysis) # the user code
# Out:
# <module 'example.an_analysis' from 'C:\Users\Toby\OneDrive\git\analysis-doc\example\an_analysis.pyc'>

# %%
os.chdir(analysis_root)
for model in ('model_1', 'model_2'):
    os.chdir(model)
    an_analysis.Demo().all_plots()
    config.Configuration().all_plots()
    os.chdir(analysis_root)
# Out:
# Saving fig plot_hist, ... to plots\demo\plot_hist_model_1.jpg
# saved local menu to plots\demo\menu.html
# saved html doc to plots\demo\index.html
# wrote menu C:\Users\Toby\OneDrive\test_plotting\model_1\plots/index.html
# saved local menu to plots\config\menu.html
# saved html doc to plots\config\index.html
# wrote menu C:\Users\Toby\OneDrive\test_plotting\model_1\plots/index.html
# Saving fig plot_hist, ... to plots\demo\plot_hist_model_2.jpg
# saved local menu to plots\demo\menu.html
# saved html doc to plots\demo\index.html
# wrote menu C:\Users\Toby\OneDrive\test_plotting\model_2\plots/index.html
# saved local menu to plots\config\menu.html
# saved html doc to plots\config\index.html
# wrote menu C:\Users\Toby\OneDrive\test_plotting\model_2\plots/index.html

# %%
reload(_html)
os.chdir(analysis_root+'model_1')
_html.HTMLindex().update_top()
# Out:
# wrote top menu C:\Users\Toby\OneDrive\test_plotting\model_1\../plot_index.html

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Toby\\OneDrive\\test_plotting\\model_1'
